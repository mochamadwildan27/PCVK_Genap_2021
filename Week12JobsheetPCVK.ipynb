# %% [markdown]
# <a href="https://colab.research.google.com/github/mochamadwildan27/PCVK_Genap_2021/blob/main/Week12JobsheetPCVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Modul 12
#
# Nama : Mochamad Wildan
#
# Kelas : TI-3F
#
# NIM : 1841720140

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
#No.2 Face Detection
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascades/haarcascade_frontalcatface.xml')

#Joko Widodo
jokowi = cv.imread('/content/drive/MyDrive/facedet/jokowi.jpg')
jokowi1 = cv.imread('/content/drive/MyDrive/facedet/jokowi.jpg')
roi_wajah1 = cascade_wajah.detectMultiScale(jokowi1) 

roi_wajah = cascade_wajah.detectMultiScale(jokowi) 
for(x,y,w,h) in roi_wajah: 
 cv.rectangle(jokowi,(x,y),(x+w,y+h),(255,0,255),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(jokowi1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(jokowi1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
plt.show()

#Raden Ajeng Kartini
kartini = cv.imread('/content/drive/MyDrive/facedet/kartini.jpg')
kartini1 = cv.imread('/content/drive/MyDrive/facedet/kartini.jpg')
roi_wajah1 = cascade_wajah.detectMultiScale(kartini1) 

roi_wajah = cascade_wajah.detectMultiScale(kartini) 
for(x,y,w,h) in roi_wajah: 
 cv.rectangle(kartini,(x,y),(x+w,y+h),(255,0,255),3) 
plt.figure(figsize = (10,10)) 

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(kartini1, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(kartini1, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
plt.show()

#NYAN
empus = cv.imread('/content/drive/MyDrive/facedet/kucing.jpg')
empus1 = cv.imread('/content/drive/MyDrive/facedet/kucing.jpg')

empus_ori = cv.cvtColor(empus, cv.COLOR_BGR2GRAY)
empus_kw = cv.cvtColor(empus1, cv.COLOR_BGR2GRAY)


roi_wajah = cascade_wajah.detectMultiScale(empus1)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(empus1,(x,y),(x+w,y+h),(255,255,255),3) 
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(empus_ori, cmap='gray')
plt.subplot(122),plt.imshow(empus_kw, cmap='gray')
plt.show()

#MASK WOMAN
mask = cv.imread('/content/drive/MyDrive/facedet/mask.png',0)
mask1 = cv.imread('/content/drive/MyDrive/facedet/mask.png',0)

roi_wajah = cascade_wajah.detectMultiScale(mask1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(mask1,(x,y),(x+w,y+h),(255,255,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(mask, cmap='gray')
plt.subplot(122),plt.imshow(mask1, cmap='gray')
plt.show() 

#MICHAEL JORDAN
jordan = cv.imread('/content/drive/MyDrive/facedet/mjordan.jpg',0)
jordan1 = cv.imread('/content/drive/MyDrive/facedet/mjordan.jpg',0)

roi_wajah = cascade_wajah.detectMultiScale(jordan1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(jordan1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(jordan, cmap='gray')
plt.subplot(122),plt.imshow(jordan1, cmap='gray')
plt.show()

#GROUPING
kelompok = cv.imread('/content/drive/MyDrive/facedet/solvayconf.jpg',0)
kelompok1 = cv.imread('/content/drive/MyDrive/facedet/solvayconf.jpg',0)

roi_wajah = cascade_wajah.detectMultiScale(kelompok1)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(kelompok1,(x,y),(x+w,y+h),(255,0,255),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kelompok, cmap='gray')
plt.subplot(122),plt.imshow(kelompok1, cmap='gray')
plt.show()

# %%
#No.3 cat face detection
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascades/haarcascade_frontalcatface.xml')

empus = cv.imread('/content/drive/MyDrive/facedet/kucing.jpg',0)
empus1 = cv.imread('/content/drive/MyDrive/facedet/kucing.jpg',0)

roi_wajah = cascade_wajah.detectMultiScale(empus1)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(empus1,(x,y),(x+w,y+h),(0,255,0),3) 
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(empus, cmap='gray')
plt.subplot(122),plt.imshow(empus1, cmap='gray')
plt.show()

# %%
#No.4 eye tracking
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascades/haarcascade_lefteye_2splits.xml') 

jokowi = cv.imread('/content/drive/MyDrive/facedet/jokowi.jpg')
jokowi_ori = cv.imread('/content/drive/MyDrive/facedet/jokowi.jpg')
jokowi_gray = cv.cvtColor(jokowi, cv.COLOR_BGR2GRAY)
jokowi_ori_gray = cv.cvtColor(jokowi_ori, cv.COLOR_BGR2GRAY)

roi_wajah = cascade_wajah.detectMultiScale(jokowi_gray)
for (x,y,w,h) in roi_wajah: 
  cv.rectangle(jokowi_gray,(x,y),(x+w,y+h),(255,255,255),3)

# Plot outputs
f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121),plt.imshow(jokowi_ori_gray, cmap='gray')
plt.subplot(122),plt.imshow(jokowi_gray, cmap='gray')
plt.show()

# %%
#No.6 blurring face
image = cv.imread('/content/drive/MyDrive/facedet/mjordan.jpg') # reads the image
image = cv.cvtColor(image, cv.COLOR_BGR2GRAY) # convert to GRAY
figure_size = 9 # the dimension of the x and y axis of the kernal.

new_image = cv.medianBlur(image, figure_size)
f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121), plt.imshow(image, cmap='gray'),plt.title('Original')
plt.subplot(122), plt.imshow(new_image, cmap='gray'),plt.title('Median Filter')
plt.show()
